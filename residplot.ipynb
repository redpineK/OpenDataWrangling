# %% [markdown]
# <a href="https://colab.research.google.com/github/redpineK/OpenDataWrangling/blob/master/residplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plotting model residuals
#
# * https://seaborn.pydata.org/examples/r...
#
#
# * lowess 란? locally weighted robust scatterplot smoothing 의 약자
#
# * 출처 : [lowess - Wiktionary](https://en.wiktionary.org/wiki/lowess)
#
# * 출처 : https://youtu.be/UMOtNeFEjaE

# %%
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Make an example dataset with y ~ x
rs = np.random.RandomState(7)
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)

# %%
# lowess: locally weighted robust scatterplot smoothing
sns.scatterplot(x=x, y=y, color="g")

# %%
# lowess: locally weighted robust scatterplot smoothing
sns.regplot(x=x, y=y, color="g", lowess=True)

# %%
# Plot the residuals after fitting a linear model
sns.residplot(x, y, lowess=True, color="g")
